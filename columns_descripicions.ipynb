# %%
import pandas as pd
import pyreadstat

# %%
df, meta =  pyreadstat.read_sav("Base de datos EHPM 2025.sav")

# %%
diccionario = pd.DataFrame({
    "Variable": meta.column_names,
    "Descripcion": meta.column_labels
})

print(diccionario.head(50))
# Out:
#                   Variable                                        Descripcion
# 0   ingreso_independientes                                                NaN
# 1             ingreso_agro                                                NaN
# 2        ingreso_pensiones                                                NaN
# 3          ingreso_remesas                                                NaN
# 4                  edicion                               Año de levantamiento
# 5                     lote                                               Lote
# 6                     tipo                                               Tipo
# 7                    folio                                              Folio
# 8                      viv                                           Vivienda
# 9                     r101                                    Número de orden
# 10                idboleta                             Identificador de hogar
# ...

# %%
diccionario[
    diccionario["Variable"]
    .str.contains("r32309b", case=False, na=False)
]
# Out:
#     Variable             Descripcion
# 243  r32309b  Número de computadoras
